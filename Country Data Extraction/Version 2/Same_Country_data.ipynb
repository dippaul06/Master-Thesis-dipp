# %%
import csv
from geopy.geocoders import Nominatim
from time import sleep
from countryinfo import CountryInfo
import pycountry
import pypopulation

# %%
data_file = '/home/dipp/Github/Master-Thesis-dipp/Country Data Extraction/Version 2/Location_with_only_country_code_V2_Latest.csv'
csv_generated_file = '/home/dipp/Github/Master-Thesis-dipp/Country Data Extraction/Version 2/Country_Data_V2_Latest.csv'

# %%
#Same Country
same_country_dict = {}

with open(data_file, newline='', encoding='utf-8') as fd:
    text_data = csv.DictReader(fd)
    count = 0
    for line in text_data:
        if((line['i']==line['j']) and (line['i']!= 'None') and (line['j']!='None')):
            count += 1
            #Country Code
            loc_code = line['i'].replace("'",'')
            
            try:
                #Country Name
                country = pycountry.countries.get(alpha_2=loc_code)
                country_name = country.name
                #Connections
                connections = float(line['count'])
                #Lat and long
                loc = Nominatim(user_agent='GetLoc')
                getloc = loc.geocode(loc_code)
                lat = getloc.latitude
                lon = getloc.longitude
                #Population
                population = pypopulation.get_population(loc_code)
                    
                #Saving all in a Dict
                same_country_dict[loc_code] = [loc_code, country_name, connections, lat, lon, population]
                sleep(1)
            except Exception:
                print(loc_code)
                continue
# Out:
# XK

# %%
same_country_dict
# Out:
# {'CA': ['CA', 'Canada', 1541103.0, 61.0666922, -107.991707, 37589262],
#  'US': ['US', 'United States', 35310671.0, 39.7837304, -100.445882, 328239523],
#  'IN': ['IN', 'India', 5133941.0, 22.3511148, 78.6677428, 1366417754],
#  'ES': ['ES', 'Spain', 203364.0, 39.3260685, -4.8379791, 47076781],
#  'AU': ['AU', 'Australia', 830736.0, -24.7761086, 134.755, 25364307],
#  'MX': ['MX', 'Mexico', 381527.0, 23.6585116, -102.0077097, 127575529],
#  'BE': ['BE', 'Belgium', 62857.0, 50.6402809, 4.6667145, 11484055],
#  'IT': ['IT', 'Italy', 336582.0, 42.6384261, 12.674297, 60297396],
#  'AR': ['AR', 'Argentina', 47085.0, -34.9964963, -64.9672817, 44938712],
#  'DE': ['DE', 'Germany', 831718.0, 51.1638175, 10.4478313, 83132799],
#  'GB': ['GB', 'United Kingdom', 3785031.0, 54.7023545, -3.2765753, 66834405],
#  'PH': ['PH', 'Philippines', 65867.0, 12.7503486, 122.7312101, 108116615],
#  'JP': ['JP', 'Japan', 560313.0, 36.5748441, 139.2394179, 126264931],
#  'VE': ['VE',
#   'Venezuela, Bolivarian Republic of',
#   100506.0,
#   8.0018709,
#   -66.1109318,
#   28515829],
#  'TR': ['TR', 'Turkey', 251923.0, 38.9597594, 34.9249653, 83429615],
#  'GR': ['GR', 'Greece', 34601.0, 38.9953683, 21.9877132, 10716322],
#  'AG': ['AG', 'Antigua and Barbuda', 2119.0, 17.2234721, -61.9554608, 97118],
#  'ZA': ['ZA', 'South Africa', 777603.0, -28.8166236, 24.991639, 58558270],
#  'MC': ['MC', 'Monaco', 6035.0, 43.7323492, 7.4276832, 38964],
#  'TH': ['TH', 'Thailand', 175278.0, 50.9014721, 11.0377839, 69625582],
#  'PA': ['PA', 'Panama', 51342.0, 8.559559, -81.1308434, 4246439],
#  'KE': ['KE', 'Kenya', 307276.0, 1.4419683, 38.4313975, 52573973],
#  'CO': ['CO', 'Colombia', 1431878.0, 4.099917, -72.9088133, 50339443],
#  'SA': ['SA', 'Saudi Arabia', 100262.0, 25.6242618, 42.3528328, 34268528],
#  'CU': ['CU', 'Cuba', 611831.0, 23.0131338, -80.8328748, 11333483],
#  'NL': ['NL',
#   'Netherlands',
#   173346.0,
#   52.24764975,
#   5.541246849406163,
#   17332850],
#  'PK': ['PK', 'Pakistan', 119170.0, 30.3308401, 71.247499, 216565318],
#  'MY': ['MY', 'Malaysia', 220897.0, 39.7837304, -100.445882, 31949777],
#  'IQ': ['IQ', 'Iraq', 9320.0, 33.0955793, 44.1749775, 39309783],
#  'SE': ['SE', 'Sweden', 47977.0, 59.6749712, 14.5208584, 10285453],
#  'HK': ['HK', 'Hong Kong', 251515.0, 22.350627, 114.1849161, 7507400],
#  'CL': ['CL', 'Chile', 40888.0, -31.7613365, -71.3187697, 18952038],
#  'ID': ['ID', 'Indonesia', 354750.0, -2.4833826, 117.8902853, 270625568],
#  'NZ': ['NZ', 'New Zealand', 26675.0, -41.5000831, 172.8344077, 4917000],
#  'PG': ['PG', 'Papua New Guinea', 4929.0, -5.6816069, 144.2489081, 8776109],
#  'NG': ['NG', 'Nigeria', 493882.0, 9.6000359, 7.9999721, 200963599],
#  'CH': ['CH', 'Switzerland', 117723.0, 46.7985624, 8.2319736, 8574832],
#  'TW': ['TW',
#   'Taiwan, Province of China',
#   30317.0,
#   23.9739374,
#   120.9820179,
#   None],
#  'EC': ['EC', 'Ecuador', 16575.0, -1.3397668, -79.3666965, 17373662],
#  'LB': ['LB', 'Lebanon', 25951.0, 33.8750629, 35.843409, 6855713],
#  'PL': ['PL', 'Poland', 81522.0, 52.215933, 19.134422, 37970874],
#  'BR': ['BR', 'Brazil', 133299.0, -10.3333333, -53.2, 211049527],
#  'IE': ['IE', 'Ireland', 27542.0, 52.865196, -7.9794599, 4941444],
#  'FR': ['FR', 'France', 93884.0, 46.603354, 1.8883335, 67059887],
#  'CM': ['CM', 'Cameroon', 3940.0, 4.6125522, 13.1535811, 25876380],
#  'BD': ['BD', 'Bangladesh', 15026.0, 24.4769288, 90.2934413, 163046161],
#  'MA': ['MA', 'Morocco', 5555.0, 31.1728205, -7.3362482, 36471769],
#  'OM': ['OM', 'Oman', 2299.0, 21.0000287, 57.0036901, 4974986],
#  'BN': ['BN', 'Brunei Darussalam', 9643.0, 4.4137155, 114.5653908, 433285],
#  'RU': ['RU',
#   'Russian Federation',
#   10925.0,
#   54.7023545,
#   -3.2765753,
#   144373535],
#  'ZW': ['ZW', 'Zimbabwe', 20154.0, -18.4554963, 29.7468414, 14645468],
#  'KR': ['KR', 'Korea, Republic of', 21779.0, 36.638392, 127.6961188, 51709098],
#  'TM': ['TM', 'Turkmenistan', 249.0, 39.3763807, 59.3924609, 5942089],
#  'DK': ['DK', 'Denmark', 30998.0, 55.670249, 10.3333283, 5818553],
#  'EG': ['EG', 'Egypt', 16753.0, 26.2540493, 29.2675469, 100388073],
#  'BS': ['BS', 'Bahamas', 4369.0, 24.7736546, -78.0000547, 389482],
#  'YT': ['YT', 'Mayotte', 750.0, 63.000147, -136.002502, None],
#  'NA': ['NA', 'Namibia', 2600.0, -23.2335499, 17.3231107, 2494530],
#  'HT': ['HT', 'Haiti', 403.0, 19.1399952, -72.3570972, 11263077],
#  'IL': ['IL', 'Israel', 29758.0, 40.0796606, -89.4337288, 9053300],
#  'PR': ['PR', 'Puerto Rico', 28449.0, 50.0874654, 14.4212535, 3193694],
#  'NO': ['NO', 'Norway', 10187.0, 61.1529386, 8.7876653, 5347896],
#  'FJ': ['FJ', 'Fiji', 3291.0, -18.1239696, 179.0122737, 889953],
#  'AT': ['AT', 'Austria', 49200.0, 47.59397, 14.12456, 8877067],
#  'NP': ['NP', 'Nepal', 17893.0, 28.1083929, 84.0917139, 28608710],
#  'VI': ['VI', 'Virgin Islands, U.S.', 881.0, 17.789187, -64.7080574, 106631],
#  'UG': ['UG', 'Uganda', 13449.0, 1.5333554, 32.2166578, 44269594],
#  'GH': ['GH', 'Ghana', 9722.0, 8.0300284, -1.0800271, 30417856],
#  'CF': ['CF',
#   'Central African Republic',
#   1281.0,
#   7.0323598,
#   19.9981227,
#   4745185],
#  'CN': ['CN', 'China', 18943.0, 35.000074, 104.999927, 1397715000],
#  'BM': ['BM', 'Bermuda', 8233.0, 32.30382, -64.7561647, 63918],
#  'SG': ['SG', 'Singapore', 3603.0, 1.357107, 103.8194992, 5703569],
#  'PT': ['PT', 'Portugal', 24777.0, 39.6621648, -8.1353519, 10269417],
#  'KW': ['KW', 'Kuwait', 8633.0, 29.2733964, 47.4979476, 4207083],
#  'UY': ['UY', 'Uruguay', 6954.0, -32.8755548, -56.0201525, 3461734],
#  'SV': ['SV', 'El Salvador', 2767.0, 13.8000382, -88.9140683, 6453553],
#  'RS': ['RS', 'Serbia', 15970.0, 44.1534121, 20.55144, 6944975],
#  'MV': ['MV', 'Maldives', 5957.0, 3.7203503, 73.2244152, 530953],
#  'CZ': ['CZ', 'Czechia', 3583.0, 49.7439047, 15.3381061, 10669709],
#  'JO': ['JO', 'Jordan', 3305.0, 31.1667049, 36.941628, 10101694],
#  'PE': ['PE', 'Peru', 6017.0, -6.8699697, -75.0458515, 32510453],
#  'LR': ['LR', 'Liberia', 281.0, 5.7499721, -9.3658524, 4937374],
#  'FI': ['FI', 'Finland', 6454.0, 63.2467777, 25.9209164, 5520314],
#  'MZ': ['MZ', 'Mozambique', 1714.0, -19.302233, 34.9144977, 30366036],
#  'AE': ['AE', 'United Arab Emirates', 5508.0, 24.0002488, 53.9994829, 9770529],
#  'HR': ['HR', 'Croatia', 3701.0, 45.3658443, 15.6575209, 4067500],
#  'UM': ['UM',
#   'United States Minor Outlying Islands',
#   323.0,
#   3.1257608,
#   101.65553478301041,
#   None],
#  'RW': ['RW', 'Rwanda', 2974.0, -1.9646631, 30.0644358, 12626950],
#  'SI': ['SI', 'Slovenia', 14648.0, 46.1199444, 14.8153333, 2087946],
#  'VG': ['VG',
#   'Virgin Islands, British',
#   993.0,
#   18.4024395,
#   -64.5661642,
#   30030],
#  'DO': ['DO',
#   'Dominican Republic',
#   14606.0,
#   19.0974031,
#   -70.3028026,
#   10738958],
#  'KH': ['KH', 'Cambodia', 1715.0, 12.5433216, 104.8144914, 16486542],
#  'TC': ['TC',
#   'Turks and Caicos Islands',
#   1001.0,
#   21.721746,
#   -71.5527809,
#   38191],
#  'VN': ['VN', 'Viet Nam', 2983.0, 15.9266657, 107.9650855, 96462106],
#  'CG': ['CG', 'Congo', 2553.0, -0.7264327, 15.6419155, 5380508],
#  'WS': ['WS', 'Samoa', 131.0, -13.7693895, -172.12005, 197097],
#  'PY': ['PY', 'Paraguay', 3119.0, -23.3165935, -58.1693445, 7044636],
#  'TZ': ['TZ',
#   'Tanzania, United Republic of',
#   3022.0,
#   -6.5247123,
#   35.7878438,
#   58005463],
#  'RO': ['RO', 'Romania', 5333.0, 45.9852129, 24.6859225, 19356544],
#  'IR': ['IR',
#   'Iran, Islamic Republic of',
#   2515.0,
#   32.6475314,
#   54.5643516,
#   82913906],
#  'AX': ['AX', 'Åland Islands', 54.0, 42.7193597, 1.8379765, None],
#  'CR': ['CR', 'Costa Rica', 609.0, 45.22086405, 10.037037979628856, 5047561],
#  'DJ': ['DJ', 'Djibouti', 3584.0, 11.8145966, 42.8453061, 973560],
#  'LS': ['LS', 'Lesotho', 369.0, 20.0171109, 103.378253, 2125268],
#  'SK': ['SK', 'Slovakia', 971.0, 48.7411522, 19.4528646, 5454073],
#  'DM': ['DM', 'Dominica', 283.0, 15.4113138, -61.3653618, 71808],
#  'BJ': ['BJ', 'Benin', 6022.0, 9.5293472, 2.2584408, 11801151],
#  'JM': ['JM', 'Jamaica', 480.0, 18.1850507, -77.3947693, 2948279],
#  'SD': ['SD', 'Sudan', 441.0, 14.5844444, 29.4917691, 42813238],
#  'ZM': ['ZM', 'Zambia', 197.0, -14.5189121, 27.5589884, 17861030],
#  'BG': ['BG', 'Bulgaria', 820.0, 42.6073975, 25.4856617, 6975761],
#  'JE': ['JE', 'Jersey', 449.0, 49.2214561, -2.1358386, None],
#  'TN': ['TN', 'Tunisia', 1310.0, 33.8439408, 9.400138, 11694719],
#  'EE': ['EE', 'Estonia', 345.0, 58.7523778, 25.3319078, 1326590],
#  'CW': ['CW', 'Curaçao', 204.0, -6.2424394, 106.8586843, 157538],
#  'GQ': ['GQ', 'Equatorial Guinea', 110.0, 1.613172, 10.5170357, 1355986],
#  'TT': ['TT', 'Trinidad and Tobago', 271.0, 10.7466905, -61.0840075, 1394973],
#  'UA': ['UA', 'Ukraine', 878.0, 49.4871968, 31.2718321, 44385155],
#  'HU': ['HU', 'Hungary', 1289.0, 47.1817585, 19.5060937, 9769949],
#  'LU': ['LU', 'Luxembourg', 125.0, 51.0012996, 22.7748497, 619896],
#  'VC': ['VC',
#   'Saint Vincent and the Grenadines',
#   545.0,
#   39.6819591,
#   -0.7654406,
#   110589],
#  'AQ': ['AQ', 'Antarctica', 246.0, 42.1368853, 13.610341022538911, None],
#  'PN': ['PN', 'Pitcairn', 22.0, -25.0657719, -130.101782, None],
#  'KY': ['KY', 'Cayman Islands', 239.0, 37.5726028, -85.1551411, 64948],
#  'LA': ['LA',
#   "Lao People's Democratic Republic",
#   136.0,
#   34.0536909,
#   -118.242766,
#   7169455],
#  'QA': ['QA', 'Qatar', 1276.0, 25.3336984, 51.2295295, 2832067],
#  'MR': ['MR', 'Mauritania', 618.0, 20.2540382, -9.2399263, 4525696],
#  'KG': ['KG', 'Kyrgyzstan', 103.0, 41.5089324, 74.724091, 6456900],
#  'MP': ['MP',
#   'Northern Mariana Islands',
#   329.0,
#   15.1753648,
#   145.7379338,
#   57216],
#  'GF': ['GF', 'French Guiana', 23.0, 48.38003005, 16.715760431090658, None],
#  'DZ': ['DZ', 'Algeria', 103.0, 28.0000272, 2.9999825, 43053054],
#  'MM': ['MM', 'Myanmar', 308.0, 17.1750495, 95.9999652, 54045420],
#  'ML': ['ML', 'Mali', 362.0, 16.3700359, -2.2900239, 19658031],
#  'CY': ['CY', 'Cyprus', 638.0, 34.9823018, 33.1451285, 1198575],
#  'BB': ['BB', 'Barbados', 84.0, 13.1500331, -59.5250305, 287025],
#  'KP': ['KP',
#   "Korea, Democratic People's Republic of",
#   63.0,
#   40.3736611,
#   127.0870417,
#   25666161],
#  'MU': ['MU', 'Mauritius', 595.0, -20.2759451, 57.5703566, 1265711],
#  'GU': ['GU', 'Guam', 225.0, 13.4499943, 144.7651677, 167294],
#  'PF': ['PF', 'French Polynesia', 108.0, 48.6164857, 9.6719927, 279287],
#  'HN': ['HN', 'Honduras', 283.0, 15.2572432, -86.0755145, 9746117],
#  'AM': ['AM', 'Armenia', 491.0, 40.7696272, 44.6736646, 2957731],
#  'CD': ['CD',
#   'Congo, The Democratic Republic of the',
#   103.0,
#   -2.9814344,
#   23.8222636,
#   86790567],
#  'BQ': ['BQ',
#   'Bonaire, Sint Eustatius and Saba',
#   25.0,
#   36.2109553,
#   54.448222,
#   None],
#  'AS': ['AS', 'American Samoa', 86.0, 26.4073841, 93.2551303, 55312],
#  'GT': ['GT', 'Guatemala', 53.0, 15.5855545, -90.345759, 16604026],
#  'LK': ['LK', 'Sri Lanka', 178.0, 7.5554942, 80.7137847, 21803000],
#  'SS': ['SS', 'South Sudan', 85.0, 7.8699431, 29.6667897, 11062113],
#  'MG': ['MG', 'Madagascar', 154.0, -18.9249604, 46.4416422, 26969307],
#  'TF': ['TF',
#   'French Southern Territories',
#   35.0,
#   60.1860107,
#   24.832667609018262,
#   None],
#  'NC': ['NC', 'New Caledonia', 57.0, 35.6729639, -79.0392919, 287800],
#  'TL': ['TL', 'Timor-Leste', 77.0, -8.7443169, 126.063482, 1293119],
#  'FM': ['FM',
#   'Micronesia, Federated States of',
#   29.0,
#   43.0922489,
#   13.638768067263769,
#   113815],
#  'BO': ['BO',
#   'Bolivia, Plurinational State of',
#   10.0,
#   -17.0568696,
#   -64.9912286,
#   11513100],
#  'PS': ['PS', 'Palestine, State of', 175.0, 34.0346534, -5.0161926, 4685306],
#  'SN': ['SN', 'Senegal', 91.0, 14.4750607, -14.4529612, 16296364],
#  'BW': ['BW', 'Botswana', 159.0, 48.53775, 9.041169, 2303697],
#  'AZ': ['AZ', 'Azerbaijan', 86.0, 40.3936294, 47.7872508, 10023318],
#  'MK': ['MK', 'North Macedonia', 128.0, 41.6171214, 21.7168387, 2083459],
#  'GG': ['GG', 'Guernsey', 235.0, 49.4566233, -2.5822348, None],
#  'IS': ['IS', 'Iceland', 77.0, 64.9841821, -18.1059013, 361313],
#  'LT': ['LT', 'Lithuania', 79.0, 55.3500003, 23.7499997, 2786844],
#  'BH': ['BH', 'Bahrain', 212.0, 44.3053476, 17.5961467, 1641172],
#  'TJ': ['TJ', 'Tajikistan', 129.0, 38.6281733, 70.8156541, 9321018],
#  'BY': ['BY', 'Belarus', 30.0, 53.4250605, 27.6971358, 9466856],
#  'BA': ['BA', 'Bosnia and Herzegovina', 16.0, 44.3053476, 17.5961467, 3301000],
#  'SY': ['SY', 'Syrian Arab Republic', 144.0, 34.6401861, 39.0494106, 17070135],
#  'AF': ['AF', 'Afghanistan', 35.0, 33.7680065, 66.2385139, 38041754],
#  'SL': ['SL', 'Sierra Leone', 79.0, 8.6400349, -11.8400269, 7813215],
#  'MW': ['MW', 'Malawi', 27.0, -13.2687204, 33.9301963, 18628747],
#  'GM': ['GM', 'Gambia', 58.0, 13.470062, -15.4900464, 2347706],
#  'LV': ['LV', 'Latvia', 142.0, 56.8406494, 24.7537645, 1912789],
#  'LI': ['LI', 'Liechtenstein', 118.0, 47.1416307, 9.5531527, 38019],
#  'SO': ['SO', 'Somalia', 61.0, 8.3676771, 49.083416, 15442905],
#  'MN': ['MN', 'Mongolia', 66.0, 45.9896587, -94.6113288, 3225167],
#  'SR': ['SR', 'Suriname', 25.0, 4.1413025, -56.0771187, 581372],
#  'GL': ['GL', 'Greenland', 58.0, 77.6192349, -42.8125967, 56225],
#  'TG': ['TG', 'Togo', 12.0, 8.7800265, 1.0199765, 8082366],
#  'AI': ['AI', 'Anguilla', 51.0, 18.1954947, -63.0750234, None],
#  'TV': ['TV', 'Tuvalu', 35.0, 45.806691349999994, 12.206315763116372, 11646],
#  'KM': ['KM', 'Comoros', 5.0, -12.2045176, 44.2832964, 850886],
#  'SZ': ['SZ', 'Eswatini', 14.0, -26.5624806, 31.3991317, 1148130],
#  'VU': ['VU', 'Vanuatu', 10.0, -16.5255069, 168.1069154, 299882],
#  'LY': ['LY', 'Libya', 52.0, 26.8234472, 18.1236723, 6777452],
#  'AL': ['AL', 'Albania', 38.0, 33.2588817, -86.8295337, 2854191],
#  'GS': ['GS',
#   'South Georgia and the South Sandwich Islands',
#   18.0,
#   -54.8432857,
#   -35.8090698,
#   None],
#  'BI': ['BI', 'Burundi', 21.0, 50.6402809, 4.6667145, 11530580],
#  'KN': ['KN', 'Saint Kitts and Nevis', 39.0, 50.776351, 6.083862, 52823],
#  'ER': ['ER', 'Eritrea', 42.0, 52.865196, -7.9794599, 3497117],
#  'BF': ['BF', 'Burkina Faso', 31.0, 12.0753083, -1.6880314, 20321378],
#  'KZ': ['KZ', 'Kazakhstan', 38.0, 48.1012954, 66.7780818, 18513930],
#  'GI': ['GI', 'Gibraltar', 20.0, 36.1285933, -5.3474761, 33701],
#  'VA': ['VA',
#   'Holy See (Vatican City State)',
#   13.0,
#   41.903411,
#   12.4528527,
#   None],
#  'GY': ['GY', 'Guyana', 6.0, 4.8417097, -58.6416891, 782766],
#  'SH': ['SH',
#   'Saint Helena, Ascension and Tristan da Cunha',
#   6.0,
#   54.1853998,
#   9.8220089,
#   None],
#  'RE': ['RE', 'Réunion', 19.0, 44.608664, 10.594796841892734, None],
#  'LC': ['LC', 'Saint Lucia', 6.0, 13.8250489, -60.975036, 182790],
#  'BZ': ['BZ', 'Belize', 2.0, 16.8259793, -88.7600927, 390353],
#  'BT': ['BT', 'Bhutan', 8.0, 27.549511, 90.5119273, 763092],
#  'AO': ['AO', 'Angola', 9.0, 47.59397, 14.12456, 31825295],
#  'YE': ['YE', 'Yemen', 8.0, 16.3471243, 47.8915271, 29161922],
#  'NI': ['NI', 'Nicaragua', 14.0, 54.5859836, -6.9591554, 6545502],
#  'MD': ['MD', 'Moldova, Republic of', 6.0, 39.5162401, -76.9382069, 2657637],
#  'IM': ['IM', 'Isle of Man', 6.0, 43.95837525, 7.866742714674276, 84584],
#  'MO': ['MO', 'Macao', 3.0, 38.7604815, -92.5617875, 640445],
#  'GE': ['GE', 'Georgia', 10.0, 41.6809707, 44.0287382, 3720382],
#  'MT': ['MT', 'Malta', 10.0, 35.8885993, 14.4476911, 502653],
#  'GN': ['GN', 'Guinea', 4.0, 8.0300284, -1.0800271, 12771246],
#  'TD': ['TD', 'Chad', 2.0, 15.6134137, 19.0156172, 15946876],
#  'UZ': ['UZ', 'Uzbekistan', 3.0, 41.32373, 63.9528098, 33580650],
#  'KI': ['KI', 'Kiribati', 1.0, 0.3448612, 173.6641773, 117606],
#  'NE': ['NE', 'Niger', 1.0, 35.000074, 104.999927, 23310715],
#  'EH': ['EH',
#   'Western Sahara',
#   1.0,
#   23.340694499999998,
#   -13.129132651166511,
#   None],
#  'GA': ['GA', 'Gabon', 1.0, -0.8999695, 11.6899699, 2172579],
#  'ME': ['ME', 'Montenegro', 1.0, 23.6585116, -102.0077097, 622137]}

# %%
same_country_dict['TW']
# Out:
# ['TW', 'Taiwan, Province of China', 30317.0, 23.9739374, 120.9820179, None]

# %%
with open(csv_generated_file, 'w', newline='') as csvfile:
    fieldnames = ['Country Code', 'Country Name', 'Connections', 'Latitude', 'Longitude', 'Population']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    for a,b in same_country_dict.items():
        Country_code = b[0]
        Country_Name = b[1]
        Connections = b[2]
        Lat = b[3]
        Long = b[4]
        Population = b[5]

        writer.writerow({'Country Code':Country_code, 'Country Name': Country_Name, 'Connections':Connections, 'Latitude':Lat, 'Longitude':Long, 'Population':Population})

# %%
import pycountry_convert as pc
continent_name = pc.country_alpha2_to_continent_code('DE')
print(continent_name)
# Out:
# EU

# %%
import pycountry_convert as pc
csv_Europe_generated_file = '/home/dipp/Github/Master-Thesis-dipp/Country Data Extraction/Version 2/Europe_Country_Data_V2_Latest.csv'

# %%
with open(csv_Europe_generated_file, 'w', newline='') as csvfile:
    fieldnames = ['Country Code', 'Country Name', 'Connections', 'Latitude', 'Longitude', 'Population']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    for a,b in same_country_dict.items():
        Country_code = b[0]
        Country_Name = b[1]
        Connections = b[2]
        Lat = b[3]
        Long = b[4]
        Population = b[5]
        
        try: 
            continent_name = pc.country_alpha2_to_continent_code(Country_code)
            if(continent_name == 'EU'):
                writer.writerow({'Country Code':Country_code, 'Country Name': Country_Name, 'Connections':Connections, 'Latitude':Lat, 'Longitude':Long, 'Population':Population})
        except Exception:
            print(Country_code)
            continue
# Out:
# UM
# AQ
# PN
# TF
# TL
# VA
# EH
