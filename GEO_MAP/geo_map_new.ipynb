# %%
import csv
from geopy.geocoders import Nominatim
from time import sleep

import folium
from folium.plugins import MarkerCluster
from folium import IFrame

# %%
data_file = '/home/dipp/Github/Master-Thesis-dipp/GEO_MAP/Data/sorted_country_code_with_count_new.csv'
results_file = '/home/dipp/Github/Master-Thesis-dipp/GEO_MAP/RESULTS/geo_map_test.html'

# %%
## Here we are keeping the Country Code, Count, retirved Latitude and Lonitude value
same_country_dict = {}

with open(data_file, newline='', encoding='utf-8') as fd:
    text_data = csv.DictReader(fd)
    count = 0
    for line in text_data:
        if((line['i']==line['j']) and (line['i']!= 'None') and (line['j']!='None')):
            count += 1
            loc_code = line['i'].replace("'",'')
            #print(count,' ',loc_code)
            try:
                loc = Nominatim(user_agent='GetLoc')
                getloc = loc.geocode(loc_code)
                lat = getloc.latitude
                lon = getloc.longitude
                same_country_dict[loc_code] = [line['count'], lat, lon]
                sleep(1)
            except Exception:
                print(loc_code)
                continue
# Out:
# GR

# %%
same_country_dict
# Out:
# {'US': ['6592788', 39.7837304, -100.445882],
#  'IN': ['1375358', 22.3511148, 78.6677428],
#  'GB': ['1014896', 54.7023545, -3.2765753],
#  'CO': ['687697', 4.099917, -72.9088133],
#  'ZA': ['269271', -28.8166236, 24.991639],
#  'CA': ['185536', 61.0666922, -107.991707],
#  'TR': ['115972', 38.9597594, 34.9249653],
#  'JP': ['115151', 36.5748441, 139.2394179],
#  'AU': ['101220', -24.7761086, 134.755],
#  'DE': ['95779', 51.1638175, 10.4478313],
#  'HK': ['95149', 22.350627, 114.1849161],
#  'CU': ['81384', 23.0131338, -80.8328748],
#  'MY': ['68483', 39.7837304, -100.445882],
#  'ID': ['61104', -2.4833826, 117.8902853],
#  'KE': ['53375', 1.4419683, 38.4313975],
#  'TH': ['44580', 50.9014721, 11.0377839],
#  'SA': ['42960', 25.6242618, 42.3528328],
#  'IT': ['39247', 42.6384261, 12.674297],
#  'NG': ['26672', 9.6000359, 7.9999721],
#  'PA': ['26108', 8.559559, -81.1308434],
#  'MX': ['24354', 23.6585116, -102.0077097],
#  'BR': ['21609', -10.3333333, -53.2],
#  'VE': ['19171', 8.0018709, -66.1109318],
#  'ES': ['19110', 39.3260685, -4.8379791],
#  'NL': ['17978', 52.24764975, 5.541246849406163],
#  'PK': ['16112', 30.3308401, 71.247499],
#  'BE': ['12730', 50.6402809, 4.6667145],
#  'SE': ['9607', 59.6749712, 14.5208584],
#  'PH': ['9347', 12.7503486, 122.7312101],
#  'AR': ['8403', -34.9964963, -64.9672817],
#  'FR': ['8267', 46.603354, 1.8883335],
#  'DK': ['7753', 55.670249, 10.3333283],
#  'PL': ['7700', 52.215933, 19.134422],
#  'ZW': ['7420', -18.4554963, 29.7468414],
#  'NP': ['7039', 28.1083929, 84.0917139],
#  'SI': ['5969', 46.1199444, 14.8153333],
#  'CH': ['5024', 46.7985624, 8.2319736],
#  'CL': ['4808', -31.7613365, -71.3187697],
#  'PT': ['4702', 39.6621648, -8.1353519],
#  'KR': ['4579', 36.638392, 127.6961188],
#  'EG': ['4285', 26.2540493, 29.2675469],
#  'BD': ['3852', 24.4769288, 90.2934413],
#  'IQ': ['3818', 33.0955793, 44.1749775],
#  'BN': ['3338', 4.4137155, 114.5653908],
#  'RU': ['2766', 54.7023545, -3.2765753],
#  'PR': ['2582', 50.0874654, 14.4212535],
#  'IE': ['2144', 52.865196, -7.9794599],
#  'NZ': ['2120', -41.5000831, 172.8344077],
#  'DJ': ['1254', 11.8145966, 42.8453061],
#  'AG': ['1113', 17.2234721, -61.9554608],
#  'DO': ['940', 19.0974031, -70.3028026],
#  'CN': ['902', 35.000074, 104.999927],
#  'MA': ['877', 31.1728205, -7.3362482],
#  'MC': ['866', 43.7323492, 7.4276832],
#  'NO': ['847', 61.1529386, 8.7876653],
#  'MV': ['748', 3.7203503, 73.2244152],
#  'CZ': ['734', 49.7439047, 15.3381061],
#  'CG': ['722', -0.7264327, 15.6419155],
#  'TC': ['708', 21.721746, -71.5527809],
#  'RS': ['644', 44.1534121, 20.55144],
#  'VN': ['633', 15.9266657, 107.9650855],
#  'GH': ['613', 8.0300284, -1.0800271],
#  'AE': ['581', 24.0002488, 53.9994829],
#  'KW': ['563', 29.2733964, 47.4979476],
#  'UG': ['553', 1.5333554, 32.2166578],
#  'FI': ['536', 63.2467777, 25.9209164],
#  'TW': ['524', 23.9739374, 120.9820179],
#  'PE': ['467', -6.8699697, -75.0458515],
#  'NA': ['428', -23.2335499, 17.3231107],
#  'TZ': ['366', -6.5247123, 35.7878438],
#  'RW': ['356', -1.9646631, 30.0644358],
#  'AT': ['355', 47.59397, 14.12456],
#  'OM': ['352', 21.0000287, 57.0036901],
#  'SG': ['346', 1.357107, 103.8194992],
#  'CM': ['330', 4.6125522, 13.1535811],
#  'PY': ['319', -23.3165935, -58.1693445],
#  'SV': ['306', 13.8000382, -88.9140683],
#  'KH': ['244', 12.5433216, 104.8144914],
#  'JE': ['223', 49.2214561, -2.1358386],
#  'MR': ['221', 20.2540382, -9.2399263],
#  'VI': ['219', 17.789187, -64.7080574],
#  'JO': ['194', 31.1667049, 36.941628],
#  'RO': ['182', 45.9852129, 24.6859225],
#  'LB': ['143', 33.8750629, 35.843409],
#  'TT': ['118', 10.7466905, -61.0840075],
#  'HR': ['115', 45.3658443, 15.6575209],
#  'MM': ['103', 17.1750495, 95.9999652],
#  'CR': ['81', 45.22086405, 10.037037979628856],
#  'IL': ['79', 40.0796606, -89.4337288],
#  'LS': ['78', 20.0171109, 103.378253],
#  'EC': ['73', -1.3397668, -79.3666965],
#  'MZ': ['42', -19.302233, 34.9144977],
#  'BH': ['40', 44.3053476, 17.5961467],
#  'FJ': ['37', -18.1239696, 179.0122737],
#  'BB': ['36', 13.1500331, -59.5250305],
#  'MP': ['33', 15.1753648, 145.7379338],
#  'TL': ['30', -8.7443169, 126.063482],
#  'KG': ['30', 41.5089324, 74.724091],
#  'LU': ['29', 51.0012996, 22.7748497],
#  'BS': ['24', 24.7736546, -78.0000547],
#  'LI': ['23', 47.1416307, 9.5531527],
#  'ZM': ['19', -14.5189121, 27.5589884],
#  'DZ': ['17', 28.0000272, 2.9999825],
#  'TM': ['15', 39.3763807, 59.3924609],
#  'GU': ['14', 13.4499943, 144.7651677],
#  'TN': ['13', 33.8439408, 9.400138],
#  'BJ': ['12', 9.5293472, 2.2584408],
#  'MK': ['12', 41.6171214, 21.7168387],
#  'IS': ['12', 64.9841821, -18.1059013],
#  'KZ': ['12', 48.1012954, 66.7780818],
#  'BY': ['11', 53.4250605, 27.6971358],
#  'KN': ['11', 50.776351, 6.083862],
#  'BG': ['10', 42.6073975, 25.4856617],
#  'ML': ['10', 16.3700359, -2.2900239],
#  'JM': ['6', 18.1850507, -77.3947693],
#  'HU': ['6', 47.1817585, 19.5060937],
#  'UY': ['6', -32.8755548, -56.0201525],
#  'LT': ['5', 55.3500003, 23.7499997],
#  'IR': ['5', 32.6475314, 54.5643516],
#  'BA': ['5', 44.3053476, 17.5961467],
#  'GY': ['5', 4.8417097, -58.6416891],
#  'LV': ['5', 56.8406494, 24.7537645],
#  'BW': ['4', 48.53775, 9.041169],
#  'BO': ['3', -17.0568696, -64.9912286],
#  'KM': ['3', -12.2045176, 44.2832964],
#  'SK': ['3', 48.7411522, 19.4528646],
#  'BM': ['3', 32.30382, -64.7561647],
#  'KY': ['3', 37.5726028, -85.1551411],
#  'AQ': ['2', 42.1368853, 13.610341022538911],
#  'EE': ['2', 58.7523778, 25.3319078],
#  'GM': ['2', 13.470062, -15.4900464],
#  'SD': ['1', 14.5844444, 29.4917691],
#  'LK': ['1', 7.5554942, 80.7137847],
#  'ME': ['1', 23.6585116, -102.0077097],
#  'NE': ['1', 35.000074, 104.999927],
#  'GT': ['1', 15.5855545, -90.345759],
#  'VA': ['1', 41.903411, 12.4528527],
#  'FM': ['1', 43.0922489, 13.638768067263769],
#  'SY': ['1', 34.6401861, 39.0494106],
#  'GE': ['1', 41.6809707, 44.0287382]}

# %%
##Crates an empty Map
world_map= folium.Map(tiles="cartodbpositron", zoom_start=10)

# %%
# %%time

##OLD

#icon=folium.DivIcon(html=f"""<div style="font-family: courier new; color: {'red'}">{"{:.0f}".format(int(b[0]))}</div>""")
for a,b in same_country_dict.items():
    lat = b[1]
    long = b[2]
    count = int(b[0])
    radius = 5
    popup_text = count
    radius = 30
    folium.CircleMarker(
    location=[lat, long],
    radius=radius,
    color="cornflowerblue",
    stroke=False,
    fill=True,
    fill_opacity=0.6,
    opacity=1,
    #popup="{} pixels".format(radius),
    popup=popup_text,
    tooltip=count,
    ).add_to(world_map)
    radius = 5
    folium.Marker(location = [lat, long],icon=folium.DivIcon(html=f"""<div font-weight: bold, style="color: {'green'};">{count}</div>"""),popup= popup_text).add_to(world_map)
# Out:
# CPU times: user 12.6 ms, sys: 4.57 ms, total: 17.2 ms
# Wall time: 15.5 ms

# %%
# %%time

m = folium.Map(tiles='cartodbpositron', zoom_start=20)

#marker_cluster = MarkerCluster().add_to(m)

for a,b in same_country_dict.items():
    count = int(b[0])
    lat = b[1]
    lon = b[2]
    radius = 20
    popup_text = count



    folium.CircleMarker(location = [lat, lon], radius=radius, tooltip=count, color="cornflowerblue", stroke=False, fill=True, fill_opacity=0.6, opacity=1).add_to(m)

    folium.map.Marker( location = [lat, lon], icon=folium.DivIcon(icon_size=(150,36),icon_anchor=(0,0),html='<div style="font-size: 7pt", font-weight: 900>%s</div>' %count), popup= popup_text).add_to(m)

    #MarkerCluster(locations=[lat, lon], popups=count).add_to(m)

    #folium.Marker(location = [lat, lon]).add_to(m)
    #folium.Marker(location = [lat, lon],icon=folium.DivIcon(html=f"""<div font-weight: bold, style="color: {'green'};">{count}</div>"""),popup= popup_text).add_to(m)

m
# Out:
# CPU times: user 11.1 ms, sys: 3.12 ms, total: 14.2 ms
# Wall time: 14.2 ms
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8e1e70b29aed947449be8c7df0d69e49 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8e1e70b29aed947449be8c7df0d69e49&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8e1e70b29aed947449be8c7df0d69e49 = L.map(
#                 &quot;map_8e1e70b29aed947449be8c7df0d69e49&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8efe411cb30dc75123fa5abe9d70d473 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8e1e70b29aed947449be8c7df0d69e49);
#
#
#             var circle_marker_ba1b30e6da1503faa35ebd1b463e21b9 = L.circleMarker(
#                 [39.7837304, -100.445882],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;cornflowerblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;cornflowerblue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1, &quot;radius&quot;: 20, &quot;stroke&quot;: false, &quot;weight&quot;: 3}
#             ).addTo(map_8e1e70b29aed947449be8c7df0d69e49);
#
#
#             circle_marker_ba1b30e6da1503faa35ebd1b463e21b9.bindTooltip(
#                 `&lt;div&gt;
#                      6592788
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_bec4c9f89f7356afc611ef74222b6547 = L.marker(
#                 [39.7837304, -100.445882],
#                 {}
#             ).addTo(map_8e1e70b29aed947449be8c7df0d69e49);
#
#
#             var div_icon_deebf5d35d547934e20f92bfaeb0203d = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 7pt\&quot;, font-weight: 900\u003e6592788\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [150, 36]});
#             marker_bec4c9f89f7356afc611ef74222b6547.setIcon(div_icon_deebf5d35d547934e20f92bfaeb0203d);
#
#
#         var popup_667aa11f1e70bab9078c32a50181025a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_46ee8be337d0a59d62599573e3a44646 = $(`&lt;div id=&quot;html_46ee8be337d0a59d62599573e3a44646&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;6592788&lt;/div&gt;`)[0];
#                 popup_667aa11f1e70bab9078c32a50181025a.setContent(html_46ee8be337d0a59d62599573e3a44646);
#
#
#
#         marker_bec4c9f89f7356afc611ef74222b6547.bindPopup(popup_667aa11f1e70bab9078c32a50181025a)
#         ;
#
#
#
#
#             var circle_marker_202b5c011265f1e981006041e05cf521 = L.circleMarker(
#                 [22.3511148, 78.6677428],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;cornflowerblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;cornflowerblue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1, &quot;radius&quot;: 20, &quot;stroke&quot;: false, &quot;weight&quot;: 3}
#             ).addTo(map_8e1e70b29aed947449be8c7df0d69e49);
#
#
#             circle_marker_202b5c011265f1e981006041e05cf521.bindTooltip(
#                 `&lt;div&gt;
#                      1375358
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_abb6a734e2928cc4a2147b87f1d3dff6 = L.marker(
#                 [22.3511148, 78.6677428],
#                 {}
#             ).addTo(map_8e1e70b29aed947449be8c7df0d69e49);
#
#
#             var div_icon_7d66ca5df1d110245c7b97e52b11372c = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 7pt\&quot;, font-weight: 900\u003e1375358\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [150, 36]});
#             marker_abb6a734e2928cc4a2147b87f1d3dff6.setIcon(div_icon_7d66ca5df1d110245c7b97e52b11372c);
#
#
#         var popup_d32c97807596e2538c4f93e7d2f977f9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3104a5eef3640f2189229b9f8a7e291d = $(`&lt;div id=&quot;html_3104a5eef3640f2189229b9f8a7e291d&quot; styl

# %%
## Results Save
m.save(results_file)
m.save('test.png')

# %%
import io
from PIL import Image

img_data = m._to_png(5)
img = Image.open(io.BytesIO(img_data))
img.save('image.png')
# Out:
# ---------------------------------------------------------------------------
# SeleniumManagerException                  Traceback (most recent call last)
# File ~/miniconda3/envs/new-conda/lib/python3.11/site-packages/selenium/webdriver/common/service.py:97, in Service.start(self)
#      96 try:
# ---> 97     path = SeleniumManager().driver_location(browser)
#      98 except WebDriverException as new_err:
#
# File ~/miniconda3/envs/new-conda/lib/python3.11/site-packages/selenium/webdriver/common/selenium_manager.py:75, in SeleniumManager.driver_location(self, browser)
#      72     browser = "iexplorer"
#      74 binary, browser_flag, browser, output_flag, output = (
# ---> 75     str(self.get_binary()),
#      76     "--browser",
#      77     browser,
#      78     "--output",
#      79     "json",
#      80 )
#      81 result = self.run((binary, browser_flag, browser, output_flag, output))
#
# File ~/miniconda3/envs/new-conda/lib/python3.11/site-packages/selenium/webdriver/common/selenium_manager.py:56, in SeleniumManager.get_binary()
#      55     tracker = "https://github.com/SeleniumHQ/selenium/issues"
# ---> 56     raise SeleniumManagerException(f"{path} is missing.  Please open an issue on {tracker}")
#      58 return path
#
# SeleniumManagerException: Message: /home/dipp/miniconda3/envs/new-conda/lib/python3.11/site-packages/selenium/webdriver/common/linux/selenium-manager is missing.  Please open an issue on https://github.com/SeleniumHQ/selenium/issues
#
#
# During handling of the above exception, another exception occurred:
#
# WebDriverException                        Traceback (most recent call last)
# Cell In[48], line 4
#       1 import io
#       2 from PIL import Image
# ----> 4 img_data = m._to_png(5)
#       5 img = Image.open(io.BytesIO(img_data))
#       6 img.save('image.png')
#
# File ~/miniconda3/envs/new-conda/lib/python3.11/site-packages/folium/folium.py:342, in Map._to_png(self, delay, driver)
#     340     options = webdriver.firefox.options.Options()
#     341     options.add_argument("--headless")
# --> 342     driver = webdriver.Firefox(options=options)
#     344 html = self.get_root().render()
#     345 with temp_html_filepath(html) as fname:
#     346     # We need the tempfile to avoid JS security issues.
#
# File ~/miniconda3/envs/new-conda/lib/python3.11/site-packages/selenium/webdriver/firefox/webdriver.py:194, in WebDriver.__init__(self, firefox_profile, firefox_binary, capabilities, proxy, executable_path, options, service_log_path, service_args, service, desired_capabilities, log_path, keep_alive)
#     192 if not self.service:
#     193     self.service = Service(executable_path, service_args=service_args, log_path=service_log_path)
# --> 194 self.service.start()
#     196 executor = FirefoxRemoteConnection(
#     197     remote_server_addr=self.service.service_url, ignore_proxy=options._ignore_local_proxy
#     198 )
#     199 super().__init__(command_executor=executor, options=options, keep_alive=True)
#
# File ~/miniconda3/envs/new-conda/lib/python3.11/site-packages/selenium/webdriver/common/service.py:100, in Service.start(self)
#      98         except WebDriverException as new_err:
#      99             logger.debug("Unable to obtain driver using Selenium Manager: " + new_err.msg)
# --> 100             raise err
#     102         self._start_process(path)
#     104 count = 0
#
# File ~/miniconda3/envs/new-conda/lib/python3.11/site-packages/selenium/webdriver/common/service.py:90, in Service.start(self)
#      83 """Starts the Service.
#      84
#      85 :Exceptions:
#      86  - WebDriverException : Raised either when it can't start the service
#      87    or when it can't connect to the service
#      88 """
#      89 try:
# ---> 90     self._start_process(self.path)
#      91 except WebDriverException as err:
#      92     if "executable needs to be in PATH" in err.msg:
#
# File ~/miniconda3/envs/new-conda/lib/python3.11/site-packages/selenium/webdriver/common/service.py:218, in Service._start_process(self, path)
#     216 except OSError as err:
#     217     if err.errno == errno.ENOENT:
# --> 218         raise WebDriverException(
#     219             f"'{os.path.basename(self.path)}' executable needs to be in PATH. {self.start_error_message}"
#     220         )
#     221     if err.errno == errno.EACCES:
#     222         raise WebDriverException(
#     223             f"'{os.path.basename(self.path)}' executable may have wrong permissions. {self.start_error_message}"
#     224         )
#
# WebDriverException: Message: 'geckodriver' executable needs to be in PATH.
