# %% [markdown]
# ## Getting coordinates from location name

# %%
from geopy.geocoders import Nominatim

loc = Nominatim(user_agent='GetLoc')

getloc = loc.geocode("UK")

print(getloc.address)

print("Latiture: ", getloc.latitude, "\n")
print("Longtitude: ", getloc.longitude)
# Out:
# United Kingdom
# Latiture:  54.7023545
#
# Longtitude:  -3.2765753

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

# %%
map = Basemap(projection='cyl', lat_0=getloc.latitude, lon_0=getloc.longitude)

map.drawmapboundary(fill_color='aqua')
map.fillcontinents(color='coral', lake_color='aqua')
map.drawcoastlines()

lons = [0, 10, -20, -20]
lats = [0, -10, 40, -20]

x,y = map(lons, lats)
map.scatter(x,y, marker='D', color='m')

plt.show()
