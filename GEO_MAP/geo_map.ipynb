# %%
import csv
from geopy.geocoders import Nominatim
from time import sleep

# %%
data_file = '/home/dipp/Github/Master-Thesis-dipp/GEO_MAP/sorted_country_code_with_count_new.csv'

# %%
same_country_dict = {}

# %%
with open(data_file, newline='', encoding='utf-8') as fd:
    text_data = csv.DictReader(fd)
    count = 0
    for line in text_data:
        if((line['i']==line['j']) and (line['i']!= 'None') and (line['j']!='None')):
            count += 1
            loc_code = line['i'].replace("'",'')
            #print(count,' ',loc_code)
            try:
                loc = Nominatim(user_agent='GetLoc')
                getloc = loc.geocode(loc_code)
                lat = getloc.latitude
                lon = getloc.longitude
                same_country_dict[loc_code] = [line['count'], lat, lon]
                sleep(1)
            except Exception:
                print(loc_code)
                continue

# %%
import folium
from folium.plugins import MarkerCluster
from folium import IFrame

# %%
#empty map
world_map_01= folium.Map(tiles="cartodbpositron", zoom_start=10)

# %%
for a,b in same_country_dict.items():
    lat = b[1]
    long = b[2]
    folium.Circle(
    radius=10000,
    location=[lat, long],
    popup=b[0],
    color="crimson",
    fill=True,
    ).add_to(world_map_01)

# %%
world_map= folium.Map(tiles="cartodbpositron", zoom_start=10)

# %%
#marker_cluster = MarkerCluster().add_to(world_map)
for a,b in same_country_dict.items():
    lat = b[1]
    long = b[2]
    radius = 5
    popup_text = int(b[0])
    #popup_text = """Country : {}<br>
    #                No. of Tweets : {}<br>"""
    #popup_text = popup_text.format(a, int(b[0]))
    folium.CircleMarker(location = [lat, long], radius=radius, popup= popup_text, fill =True).add_to(world_map)

# %%
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c182951bdf36bb59e2bcb75a354a3ee3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c182951bdf36bb59e2bcb75a354a3ee3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c182951bdf36bb59e2bcb75a354a3ee3 = L.map(
#                 &quot;map_c182951bdf36bb59e2bcb75a354a3ee3&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c0b97f4114884f2597ceb923a0becf0e = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c182951bdf36bb59e2bcb75a354a3ee3);
#
#
#             var circle_marker_3b0d0f5120bbe12cbbfc8ab69758142a = L.circleMarker(
#                 [39.7837304, -100.445882],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c182951bdf36bb59e2bcb75a354a3ee3);
#
#
#         var popup_b043806652d09ccdc46e5cd076e3226d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_85ddaf29f71146931e9f79bb78145905 = $(`&lt;div id=&quot;html_85ddaf29f71146931e9f79bb78145905&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;6592788&lt;/div&gt;`)[0];
#                 popup_b043806652d09ccdc46e5cd076e3226d.setContent(html_85ddaf29f71146931e9f79bb78145905);
#
#
#
#         circle_marker_3b0d0f5120bbe12cbbfc8ab69758142a.bindPopup(popup_b043806652d09ccdc46e5cd076e3226d)
#         ;
#
#
#
#
#             var circle_marker_979e92a8b9f8d9a0ccfd7e965599e27f = L.circleMarker(
#                 [22.3511148, 78.6677428],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c182951bdf36bb59e2bcb75a354a3ee3);
#
#
#         var popup_f5de6102aa53d7106a3330b647dfbc9e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_36c4ba22ebe9245d393aaabc0c8e7eca = $(`&lt;div id=&quot;html_36c4ba22ebe9245d393aaabc0c8e7eca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1375358&lt;/div&gt;`)[0];
#                 popup_f5de6102aa53d7106a3330b647dfbc9e.setContent(html_36c4ba22ebe9245d393aaabc0c8e7eca);
#
#
#
#         circle_marker_979e92a8b9f8d9a0ccfd7e965599e27f.bindPopup(popup_f5de6102aa53d7106a3330b647dfbc9e)
#         ;
#
#
#
#
#             var circle_marker_637adc5865da05a5d7142401893123d5 = L.circleMarker(
#                 [54.7023545, -3.2765753],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c182951bdf36bb59e2bcb75a354a3ee3);
#
#
#         var popup_c5544c977d1fa75b00b04be582a2f2d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ac4941f189bf2471969e7cbc6364165a = $(`&lt;div id=&quot;html_ac4941f189bf2471969e7cbc6364165a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1014896&lt;/div&gt;`)[0];
#                 popup_c5544c977d1fa75b00b04be582a2f2d8.setContent(html_ac4941f189bf2471969e7cbc6364165a);
#
#
#
#         circle_marker_637adc5865da05a5d7142401893123d5.bindPopup(popup_c5544c977d1fa75b00b04be582a2f2d8)
#         ;
#
#
#
#
#             var circle_marker_ba7d7fa549e24fc526df9c6679d36b5d = L.circleMarker(
#                 [4.099917, -72.9088133],

# %%
world_map.save('first_map.html')
