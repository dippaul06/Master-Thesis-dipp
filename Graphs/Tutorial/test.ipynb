# %%
import pandas as pd
df = pd.read_csv('data.csv')

# %%
df1 = df[['Assignee', 'Reporter']]

# %%
import networkx as nx
G = nx.Graph()

# %%
G = nx.from_pandas_edgelist(df1, 'Assignee', 'Reporter')

# %%
from matplotlib.pyplot import figure
figure(figsize=(10, 8))
nx.draw_shell(G, with_labels=True)

# %%
leaderboard = {}
for x in G.nodes:
 leaderboard[x] = len(G[x])
s = pd.Series(leaderboard, name='connections')
df2 = s.to_frame().sort_values('connections', ascending=False)

# %%
df2.head()
# Out:
#                 connections
# susan.lee                22
# barbie.doll              11
# joe.appleseed            11
# edward.johnson            8
# NaN                       8

# %%
import pandas as pd
import networkit as nt

# %%
df = pd.read_csv("/home/dipp/Github/Graphs/data.csv")
df["i"] = df["i"].astype(str).astype(int)
df["j"] = df["j"].astype(str).astype(int)
df["contacts"] = df["contacts"].astype(str).astype(int)
df["mentions"] = df["mentions"].astype(str).astype(int)

df1 = df[['i']]
df2 = df[['j']]
df3 = df[['contacts']]
df4 = df[['mentions']]

# %%
G1 = nt.graph.Graph(weighted=True)
Graph1 = G1.addEdge(u=df1,v=df2,w=df3)
Graph1 = G1.addEdge(u=df1,v=df2,w=df4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_13205/3373207947.py in <module>
#       1 G1 = nt.graph.Graph(weighted=True)
# ----> 2 Graph1 = G1.addEdge(u=df1,v=df2,w=df3)
#       3 Graph1 = G1.addEdge(u=df1,v=df2,w=df4)
#
# networkit/graph.pyx in networkit.graph.Graph.addEdge()
#
# TypeError: an integer is required

# %%
import pandas as pd
import networkit as nt
import networkx as nx

# %%
df = pd.read_csv("/home/dipp/Github/Graphs/data.csv")
df1 = df[['i']]
df2 = df[['j']]
df3 = df[['contacts']]
df4 = df[['mentions']]

# %%
Gp1 = nx.from_pandas_edgelist(df=df, source='i', target='j', edge_attr='contacts', create_using=nx.DiGraph)
Gp2 = nx.from_pandas_edgelist(df=df, source='i', target='j', edge_attr='mentions')

# %%
Dg1 = Gp1.to_directed()

# %%
nodes = nx.number_of_nodes(Dg1)
edges = nx.number_of_edges(Dg1)

# %%
nodes1 = nx.number_of_nodes(Gp1)
nodes2 = nx.number_of_nodes(Gp2)

# %%
edges1 = nx.number_of_edges(Gp1)
edges2 = nx.number_of_edges(Gp2)

# %%
degree1 = nx.degree(Gp1)
degree2 = nx.degree(Gp2)

# %%
degree1
# Out:
# DiDegreeView({849588931263832064: 1, 2450621492: 1, 1020058453: 1, 18965007: 1, 1383272101: 1, 800168637109633024: 1, 1045110787: 1, 325885589: 1, 111527043: 1, 1189494217661407233: 1, 9130702: 1, 2786857361: 1, 467571978: 1, 1050900986368335873: 1, 918804624303382528: 1, 115570410: 1, 1133245400423522304: 1, 259289426: 1})

# %%
cluster1 = nx.clustering(Gp1)
cluster2 = nx.clustering(Gp2)

# %%
cluster2
# Out:
# {849588931263832064: 0,
#  2450621492: 0,
#  1020058453: 0,
#  18965007: 0,
#  1383272101: 0,
#  800168637109633024: 0,
#  1045110787: 0,
#  325885589: 0,
#  111527043: 0,
#  1189494217661407233: 0,
#  9130702: 0,
#  2786857361: 0,
#  467571978: 0,
#  1050900986368335873: 0,
#  918804624303382528: 0,
#  115570410: 0,
#  1133245400423522304: 0,
#  259289426: 0}

# %%
vs1 = nx.draw(Gp1)
vs2 = nx.draw(Gp2)

# %%
nx.write_gpickle(Gp1, "/home/dipp/Github/Graphs/test1.gpickle")
nx.write_graphml(Gp1, "/home/dipp/Github/Graphs/test1.graphml")

# %%
import pandas as pd
import networkit as nt
import networkx as nx

# %%
df = pd.read_csv("/home/dipp/Github/Graphs/data.csv")
Graph = nx.from_pandas_edgelist(df=df, source='i', target='j', edge_attr='contacts')
#Dgraph = nx.to_directed(Graph)
Dgraph = nx.DiGraph()

# %%
import numpy as np
import networkx as nx

# %%
arr = np.genfromtxt("/home/dipp/Github/Graphs/data.csv", delimiter=",", dtype=str)
new_arr = arr[:,:3]

# %%
display(new_arr)
# Out:
# array([['i', 'j', 'contacts'],
#        ['849588931263832064', '2450621492', '1'],
#        ['1020058453', '18965007', '1'],
#        ['1383272101', '800168637109633024', '32'],
#        ['1045110787', '325885589', '3'],
#        ['111527043', '1189494217661407233', '6'],
#        ['9130702', '2786857361', '2'],
#        ['467571978', '1050900986368335873', '8'],
#        ['918804624303382528', '115570410', '10'],
#        ['1133245400423522304', '259289426', '1']], dtype='<U19')

# %%
import pandas as pd
import networkit as nt
import networkx as nx
import csv

# %%
df = pd.read_csv("/home/dipp/Github/Graphs/data.csv")

# %%
Graph = nx.from_pandas_edgelist(df=df, source='i', target='j', edge_attr='contacts', create_using=nx.DiGraph)

# %%
nodes = nx.number_of_nodes(Graph)
edges = nx.number_of_edges(Graph)
degree_list_all = Graph.degree()
degree_list_in = Graph.in_degree()
degree_list_out = Graph.out_degree()
local_cluster_conefficient = nx.clustering(Graph)

# %%
con_degree_list_all = [k for k in degree_list_all]
con_degree_list_in = [k for k in degree_list_in]
con_degree_list_out = [k for k in degree_list_out]
con_local_cluster_conefficient = list(local_cluster_conefficient.items())

# %%
with open("/home/dipp/Github/Graphs/Results/degree_all.csv", 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerows(con_degree_list_all)

with open("/home/dipp/Github/Graphs/Results/degree_in.csv", 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerows(con_degree_list_in)

with open("/home/dipp/Github/Graphs/Results/degree_out.csv", 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerows(con_degree_list_out)

with open("/home/dipp/Github/Graphs/Results/local_cluster.csv", 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerows(con_local_cluster_conefficient)

# %%
field_names = ["Node", "Cluster"]
with open("/home/dipp/Github/Graphs/Results/local_cluster.csv", 'w', newline='') as f:
    writer = csv.DictWriter(f, fieldnames=field_names)
    writer.writeheader()
    writer.writerows(local_cluster_conefficient)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_6858/3959317594.py in <module>
#       3     writer = csv.DictWriter(f, fieldnames=field_names)
#       4     writer.writeheader()
# ----> 5     writer.writerows(local_cluster_conefficient)
#
# ~/miniconda3/lib/python3.7/csv.py in writerows(self, rowdicts)
#     156
#     157     def writerows(self, rowdicts):
# --> 158         return self.writer.writerows(map(self._dict_to_list, rowdicts))
#     159
#     160 # Guard Sniffer's type checking against builds that exclude complex()
#
# ~/miniconda3/lib/python3.7/csv.py in _dict_to_list(self, rowdict)
#     146     def _dict_to_list(self, rowdict):
#     147         if self.extrasaction == "raise":
# --> 148             wrong_fields = rowdict.keys() - self.fieldnames
#     149             if wrong_fields:
# ...

# %%
type(local_cluster_conefficient)
# Out:
# dict

# %%
display(local_cluster_conefficient)
# Out:
# {849588931263832064: 0,
#  2450621492: 0,
#  1020058453: 0,
#  18965007: 0,
#  1383272101: 0,
#  800168637109633024: 0,
#  1045110787: 0,
#  325885589: 0,
#  111527043: 0,
#  1189494217661407233: 0,
#  9130702: 0,
#  2786857361: 0,
#  467571978: 0,
#  1050900986368335873: 0,
#  918804624303382528: 0,
#  115570410: 0,
#  1133245400423522304: 0,
#  259289426: 0}

# %%
print("Number of Nodes = ", nodes)
# Out:
# Number of Nodes =  18

# %%
for k in degree_list_all:
    display(k)
# Out:
# (849588931263832064, 1)
# (2450621492, 1)
# (1020058453, 1)
# (18965007, 1)
# (1383272101, 1)
# (800168637109633024, 1)
# (1045110787, 1)
# (325885589, 1)
# (111527043, 1)
# (1189494217661407233, 1)
# (9130702, 1)
# (2786857361, 1)
# (467571978, 1)
# (1050900986368335873, 1)
# (918804624303382528, 1)
# (115570410, 1)
# (1133245400423522304, 1)
# (259289426, 1)

# %%
p = [k for k in local_cluster_conefficient]

# %%
p
# Out:
# [849588931263832064,
#  2450621492,
#  1020058453,
#  18965007,
#  1383272101,
#  800168637109633024,
#  1045110787,
#  325885589,
#  111527043,
#  1189494217661407233,
#  9130702,
#  2786857361,
#  467571978,
#  1050900986368335873,
#  918804624303382528,
#  115570410,
#  1133245400423522304,
#  259289426]
