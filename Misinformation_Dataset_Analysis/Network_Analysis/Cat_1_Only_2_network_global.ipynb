# %%
import csv
import pandas as pd
import networkx as nx

# %%
data_file = '/global/D1/projects/umod/dipp/Misinformation_Dataset/Result/location_with_value/Location_with_only_country_code_cat_1_only_2.csv'
population_data_file = '/home/dipp/Github/Master-Thesis-dipp/Misinformation_Dataset_Analysis/Country_Data_Extraction/Result/Country_Data_cat_1_only_2.csv'

# %%
## Includes self Loops

country_data = {}
with open(data_file, newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    count = 0
    for row in reader:
        if(row['i'] != 'None' and row['j'] != 'None'):
            
            souce_loc = row['i'].replace("'","")
            destination_loc = row['j'].replace("'","")
            #country_data[count] = [row['i'], row['j'], float(row['count'])]
            #if(float(row['count']) > 999):
            country_data[count] = [souce_loc, destination_loc, float(row['count'])]
            count+=1

# %%
df = pd.DataFrame.from_dict(country_data, orient='index', columns=['Source','Destination','Number of Tweets'])

# %%
df
# Out:
#     Source Destination  Number of Tweets
# 0       US          US            2107.0
# 1       HK          HK               2.0
# 2       AU          AU              44.0
# 3       GB          GB             106.0
# 4       CA          CA              55.0
# ..     ...         ...               ...
# 114     GB          MX               1.0
# 115     PK          US               1.0
# 116     US          MV               1.0
# 117     NG          GB               1.0
# 118     SK          CA               1.0
#
# [119 rows x 3 columns]

# %% [markdown]
# ## Creating Graph using Networkx

# %%
G = nx.from_pandas_edgelist(df, source='Source', target='Destination', edge_attr='Number of Tweets', create_using=nx.DiGraph())

# %%
G.degree(weight='Number of Tweets')['US']
G.in_degree(weight='Number of Tweets')['US']
G.out_degree(weight='Number of Tweets')['US']
# Out:
# 2349.0

# %%
country = []
deg = G.degree(weight='Number of Tweets')
deg_in = G.in_degree(weight='Number of Tweets')
deg_out = G.out_degree(weight='Number of Tweets')

# %%
df['All Degree of Source'] = ''
df['All Degree of Destination'] = ''
df['Vi - Out Degree of Source'] = ''
df['Vj - In Degree of Destination'] = ''
# df['Percentage of Incoming'] = ''
# df['Total No. of Tweets/Population'] = ''
df
# Out:
#     Source Destination  Number of Tweets All Degree of Source  \
# 0       US          US            2107.0
# 1       HK          HK               2.0
# 2       AU          AU              44.0
# 3       GB          GB             106.0
# 4       CA          CA              55.0
# ..     ...         ...               ...                  ...
# 114     GB          MX               1.0
# 115     PK          US               1.0
# 116     US          MV               1.0
# 117     NG          GB               1.0
# 118     SK          CA               1.0
#
#     All Degree of Destination Vi - Out Degree of Source  \
# 0
# 1
# 2
# 3
# 4
# ..                        ...                       ...
# 114
# 115
# 116
# 117
# 118
#
#     Vj - In Degree of Destination
# 0
# 1
# 2
# 3
# 4
# ..                            ...
# 114
# 115
# 116
# 117
# 118
#
# [119 rows x 7 columns]

# %%
for index_df, row in df.iterrows():
    i = row['Source']
    j = row['Destination']

    for country_temp, deg_all in deg:
        if(country_temp == i):
            df.at[index_df, 'All Degree of Source'] = deg_all
        if(country_temp == j):
            df.at[index_df, 'All Degree of Destination'] = deg_all
    
    # Vj is in degree of destination

    for country_temp_in, deg_j in deg_in:
        if(country_temp_in == j):
            df.at[index_df, 'Vj - In Degree of Destination'] = deg_j
        # else:
        #     df.at[index_df, 'Vj - In Degree of Destination'] = 0
        

    # Vi is out degree of source

    for country_temp_out, deg_i in deg_out:
        if(country_temp_out == i):
            df.at[index_df, 'Vi - Out Degree of Source'] = deg_i
        # else:
        #     df.at[index_df, 'Vi - Out Degree of Source'] = 0

# %%
df
# Out:
#     Source Destination  Number of Tweets All Degree of Source  \
# 0       US          US            2107.0               4564.0
# 1       HK          HK               2.0                 10.0
# 2       AU          AU              44.0                133.0
# 3       GB          GB             106.0                365.0
# 4       CA          CA              55.0                234.0
# ..     ...         ...               ...                  ...
# 114     GB          MX               1.0                365.0
# 115     PK          US               1.0                  1.0
# 116     US          MV               1.0               4564.0
# 117     NG          GB               1.0                  8.0
# 118     SK          CA               1.0                  1.0
#
#     All Degree of Destination Vi - Out Degree of Source  \
# 0                      4564.0                    2349.0
# 1                        10.0                       4.0
# 2                       133.0                      64.0
# 3                       365.0                     161.0
# 4                       234.0                      86.0
# ..                        ...                       ...
# 114                       8.0                     161.0
# 115                    4564.0                       1.0
# 116                       1.0                    2349.0
# 117                     365.0                       3.0
# 118                     234.0                       1.0
#
#     Vj - In Degree of Destination
# 0                          2215.0
# 1                             6.0
# 2                            69.0
# 3                           204.0
# 4                           148.0
# ..                            ...
# 114                           3.0
# 115                        2215.0
# 116                           1.0
# 117                         204.0
# 118                         148.0
#
# [119 rows x 7 columns]

# %%
df['Percentage of Incoming at Destination (Total Tweet / Vj)'] = ''
df['Percentage of Outgoing From Source (Total Tweet / Vi)'] = ''
df
# Out:
#     Source Destination  Number of Tweets All Degree of Source  \
# 0       US          US            2107.0               4564.0
# 1       HK          HK               2.0                 10.0
# 2       AU          AU              44.0                133.0
# 3       GB          GB             106.0                365.0
# 4       CA          CA              55.0                234.0
# ..     ...         ...               ...                  ...
# 114     GB          MX               1.0                365.0
# 115     PK          US               1.0                  1.0
# 116     US          MV               1.0               4564.0
# 117     NG          GB               1.0                  8.0
# 118     SK          CA               1.0                  1.0
#
#     All Degree of Destination Vi - Out Degree of Source  \
# 0                      4564.0                    2349.0
# 1                        10.0                       4.0
# 2                       133.0                      64.0
# 3                       365.0                     161.0
# 4                       234.0                      86.0
# ..                        ...                       ...
# 114                       8.0                     161.0
# 115                    4564.0                       1.0
# 116                       1.0                    2349.0
# 117                     365.0                       3.0
# 118                     234.0                       1.0
#
#     Vj - In Degree of Destination  \
# 0                          2215.0
# 1                             6.0
# 2                            69.0
# 3                           204.0
# 4                           148.0
# ..                            ...
# 114                           3.0
# 115                        2215.0
# 116                           1.0
# 117                         204.0
# 118                         148.0
#
#     Percentage of Incoming at Destination (Total Tweet / Vj)  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 114
# 115
# 116
# 117
# 118
#
#     Percentage of Outgoing From Source (Total Tweet / Vi)
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 114
# 115
# 116
# 117
# 118
#
# [119 rows x 9 columns]

# %%
for index_df, row in df.iterrows():
    source = row['Source']
    destination = row['Destination']
    No_of_Tweets = row['Number of Tweets']
    vi = row['Vi - Out Degree of Source']
    vj = row['Vj - In Degree of Destination']

    per_in = float(No_of_Tweets / vj) * 100
    per_out = float(No_of_Tweets / vi) * 100
    df.at[index_df, 'Percentage of Incoming at Destination (Total Tweet / Vj)'] = per_in
    df.at[index_df, 'Percentage of Outgoing From Source (Total Tweet / Vi)'] = per_out

# %%
df
# Out:
#     Source Destination  Number of Tweets All Degree of Source  \
# 0       US          US            2107.0               4564.0
# 1       HK          HK               2.0                 10.0
# 2       AU          AU              44.0                133.0
# 3       GB          GB             106.0                365.0
# 4       CA          CA              55.0                234.0
# ..     ...         ...               ...                  ...
# 114     GB          MX               1.0                365.0
# 115     PK          US               1.0                  1.0
# 116     US          MV               1.0               4564.0
# 117     NG          GB               1.0                  8.0
# 118     SK          CA               1.0                  1.0
#
#     All Degree of Destination Vi - Out Degree of Source  \
# 0                      4564.0                    2349.0
# 1                        10.0                       4.0
# 2                       133.0                      64.0
# 3                       365.0                     161.0
# 4                       234.0                      86.0
# ..                        ...                       ...
# 114                       8.0                     161.0
# 115                    4564.0                       1.0
# 116                       1.0                    2349.0
# 117                     365.0                       3.0
# 118                     234.0                       1.0
#
#     Vj - In Degree of Destination  \
# 0                          2215.0
# 1                             6.0
# 2                            69.0
# 3                           204.0
# 4                           148.0
# ..                            ...
# 114                           3.0
# 115                        2215.0
# 116                           1.0
# 117                         204.0
# 118                         148.0
#
#     Percentage of Incoming at Destination (Total Tweet / Vj)  \
# 0                                            95.124153
# 1                                            33.333333
# 2                                            63.768116
# 3                                            51.960784
# 4                                            37.162162
# ..                                                 ...
# 114                                          33.333333
# 115                                           0.045147
# 116                                              100.0
# 117                                           0.490196
# 118                                           0.675676
#
#     Percentage of Outgoing From Source (Total Tweet / Vi)
# 0                                            89.697744
# 1                                                 50.0
# 2                                                68.75
# 3                                            65.838509
# 4                                            63.953488
# ..                                                 ...
# 114                                           0.621118
# 115                                              100.0
# 116                                           0.042571
# 117                                          33.333333
# 118                                              100.0
#
# [119 rows x 9 columns]

# %% [markdown]
# ## Extensions

# %% [markdown]
# ### Tweets per population and 2 versions of Cij

# %%
population_data = {}

with open(population_data_file, newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    
    for row in reader:
        # print(row['Country Code'])
        # print(row['Population'])
        if(row['Population']!=''):
            population_data[row['Country Code']] = int(row['Population'])

# %%
population_data['AI'] = 15753
population_data['AQ'] = 3000
population_data['AX'] = 30129
population_data['BQ'] = 27726
population_data['CX'] = 1692
population_data['EH'] = 612000
population_data['FK'] = 3662
population_data['GF'] = 301099
population_data['GG'] = 63950
population_data['GS'] = 1
population_data['IO'] = 3000
population_data['JE'] = 103267
population_data['PN'] = 47
population_data['RE'] = 873102
population_data['SH'] = 4439
population_data['TF'] = 300
population_data['TW'] = 23894394
population_data['UM'] = 300
population_data['VA'] = 453
population_data['YT'] = 310022

# %%
df['Tweets Per Population'] = ''
df['Cij (All Degrees)'] = ''
df['Cij'] = ''

# %%
df
# Out:
#     Source Destination  Number of Tweets All Degree of Source  \
# 0       US          US            2107.0               4564.0
# 1       HK          HK               2.0                 10.0
# 2       AU          AU              44.0                133.0
# 3       GB          GB             106.0                365.0
# 4       CA          CA              55.0                234.0
# ..     ...         ...               ...                  ...
# 114     GB          MX               1.0                365.0
# 115     PK          US               1.0                  1.0
# 116     US          MV               1.0               4564.0
# 117     NG          GB               1.0                  8.0
# 118     SK          CA               1.0                  1.0
#
#     All Degree of Destination Vi - Out Degree of Source  \
# 0                      4564.0                    2349.0
# 1                        10.0                       4.0
# 2                       133.0                      64.0
# 3                       365.0                     161.0
# 4                       234.0                      86.0
# ..                        ...                       ...
# 114                       8.0                     161.0
# 115                    4564.0                       1.0
# 116                       1.0                    2349.0
# 117                     365.0                       3.0
# 118                     234.0                       1.0
#
#     Vj - In Degree of Destination  \
# 0                          2215.0
# 1                             6.0
# 2                            69.0
# 3                           204.0
# 4                           148.0
# ..                            ...
# 114                           3.0
# 115                        2215.0
# 116                           1.0
# 117                         204.0
# 118                         148.0
#
#     Percentage of Incoming at Destination (Total Tweet / Vj)  \
# 0                                            95.124153
# 1                                            33.333333
# 2                                            63.768116
# 3                                            51.960784
# 4                                            37.162162
# ..                                                 ...
# 114                                          33.333333
# 115                                           0.045147
# 116                                              100.0
# 117                                           0.490196
# 118                                           0.675676
#
#     Percentage of Outgoing From Source (Total Tweet / Vi)  \
# 0                                            89.697744
# 1                                                 50.0
# 2                                                68.75
# 3                                            65.838509
# 4                                            63.953488
# ..                                                 ...
# 114                                           0.621118
# 115                                              100.0
# 116                                           0.042571
# 117                                          33.333333
# 118                                              100.0
#
#     Tweets Per Population Cij (All Degrees) Cij
# 0
# 1
# 2
# 3
# 4
# ..                    ...               ...  ..
# 114
# 115
# 116
# 117
# 118
#
# [119 rows x 12 columns]

# %%
import pypopulation

# %%
temp = 0
None_Type_Countries = []
for index_df, row in df.iterrows():
    source = row['Source']
    destination = row['Destination']
    No_of_Tweets = row['Number of Tweets']


    # source_poplation = population_data.get(source)
    # dest_population = population_data.get(destination)


    source_poplation = pypopulation.get_population(source)
    dest_population = pypopulation.get_population(destination)

    if(source_poplation == None):
        source_poplation = population_data.get(source)
            

    if(dest_population == None):
        dest_population = population_data.get(destination)
            

    percentage = No_of_Tweets / (source_poplation + dest_population)

    df.at[index_df, 'Tweets Per Population'] = percentage

# %%
df
# Out:
#     Source Destination  Number of Tweets All Degree of Source  \
# 0       US          US            2107.0               4564.0
# 1       HK          HK               2.0                 10.0
# 2       AU          AU              44.0                133.0
# 3       GB          GB             106.0                365.0
# 4       CA          CA              55.0                234.0
# ..     ...         ...               ...                  ...
# 114     GB          MX               1.0                365.0
# 115     PK          US               1.0                  1.0
# 116     US          MV               1.0               4564.0
# 117     NG          GB               1.0                  8.0
# 118     SK          CA               1.0                  1.0
#
#     All Degree of Destination Vi - Out Degree of Source  \
# 0                      4564.0                    2349.0
# 1                        10.0                       4.0
# 2                       133.0                      64.0
# 3                       365.0                     161.0
# 4                       234.0                      86.0
# ..                        ...                       ...
# 114                       8.0                     161.0
# 115                    4564.0                       1.0
# 116                       1.0                    2349.0
# 117                     365.0                       3.0
# 118                     234.0                       1.0
#
#     Vj - In Degree of Destination  \
# 0                          2215.0
# 1                             6.0
# 2                            69.0
# 3                           204.0
# 4                           148.0
# ..                            ...
# 114                           3.0
# 115                        2215.0
# 116                           1.0
# 117                         204.0
# 118                         148.0
#
#     Percentage of Incoming at Destination (Total Tweet / Vj)  \
# 0                                            95.124153
# 1                                            33.333333
# 2                                            63.768116
# 3                                            51.960784
# 4                                            37.162162
# ..                                                 ...
# 114                                          33.333333
# 115                                           0.045147
# 116                                              100.0
# 117                                           0.490196
# 118                                           0.675676
#
#     Percentage of Outgoing From Source (Total Tweet / Vi)  \
# 0                                            89.697744
# 1                                                 50.0
# 2                                                68.75
# 3                                            65.838509
# 4                                            63.953488
# ..                                                 ...
# 114                                           0.621118
# 115                                              100.0
# 116                                           0.042571
# 117                                          33.333333
# 118                                              100.0
#
#     Tweets Per Population Cij (All Degrees) Cij
# 0                0.000003
# 1                     0.0
# 2                0.000001
# 3                0.000001
# 4                0.000001
# ..                    ...               ...  ..
# 114                   0.0
# 115                   0.0
# 116                   0.0
# 117                   0.0
# 118                   0.0
#
# [119 rows x 12 columns]

# %%
for index_df, row in df.iterrows():
    source = row['Source']
    destination = row['Destination']
    No_of_Tweets = row['Number of Tweets']
    all_degree_source = row['All Degree of Source']
    all_degree_dest = row['All Degree of Destination']
    vi = row['Vi - Out Degree of Source']
    vj = row['Vj - In Degree of Destination']


    cij_all = No_of_Tweets / (all_degree_source + all_degree_dest)
    cij = No_of_Tweets / (vi + vj)

    df.at[index_df, 'Cij (All Degrees)'] = cij_all
    df.at[index_df, 'Cij'] = cij

# %%
df
# Out:
#     Source Destination  Number of Tweets All Degree of Source  \
# 0       US          US            2107.0               4564.0
# 1       HK          HK               2.0                 10.0
# 2       AU          AU              44.0                133.0
# 3       GB          GB             106.0                365.0
# 4       CA          CA              55.0                234.0
# ..     ...         ...               ...                  ...
# 114     GB          MX               1.0                365.0
# 115     PK          US               1.0                  1.0
# 116     US          MV               1.0               4564.0
# 117     NG          GB               1.0                  8.0
# 118     SK          CA               1.0                  1.0
#
#     All Degree of Destination Vi - Out Degree of Source  \
# 0                      4564.0                    2349.0
# 1                        10.0                       4.0
# 2                       133.0                      64.0
# 3                       365.0                     161.0
# 4                       234.0                      86.0
# ..                        ...                       ...
# 114                       8.0                     161.0
# 115                    4564.0                       1.0
# 116                       1.0                    2349.0
# 117                     365.0                       3.0
# 118                     234.0                       1.0
#
#     Vj - In Degree of Destination  \
# 0                          2215.0
# 1                             6.0
# 2                            69.0
# 3                           204.0
# 4                           148.0
# ..                            ...
# 114                           3.0
# 115                        2215.0
# 116                           1.0
# 117                         204.0
# 118                         148.0
#
#     Percentage of Incoming at Destination (Total Tweet / Vj)  \
# 0                                            95.124153
# 1                                            33.333333
# 2                                            63.768116
# 3                                            51.960784
# 4                                            37.162162
# ..                                                 ...
# 114                                          33.333333
# 115                                           0.045147
# 116                                              100.0
# 117                                           0.490196
# 118                                           0.675676
#
#     Percentage of Outgoing From Source (Total Tweet / Vi)  \
# 0                                            89.697744
# 1                                                 50.0
# 2                                                68.75
# 3                                            65.838509
# 4                                            63.953488
# ..                                                 ...
# 114                                           0.621118
# 115                                              100.0
# 116                                           0.042571
# 117                                          33.333333
# 118                                              100.0
#
#     Tweets Per Population Cij (All Degrees)       Cij
# 0                0.000003          0.230828  0.461656
# 1                     0.0               0.1       0.2
# 2                0.000001          0.165414  0.330827
# 3                0.000001          0.145205  0.290411
# 4                0.000001          0.117521  0.235043
# ..                    ...               ...       ...
# 114                   0.0          0.002681  0.006098
# 115                   0.0          0.000219  0.000451
# 116                   0.0          0.000219  0.000426
# 117                   0.0          0.002681  0.004831
# 118                   0.0          0.004255  0.006711
#
# [119 rows x 12 columns]

# %%
df.to_csv('/home/dipp/Github/Master-Thesis-dipp/Misinformation_Dataset_Analysis/Network_Analysis/Result/global_network_cat_1_only_2.csv', index=False)
