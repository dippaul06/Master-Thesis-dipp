# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
shapefile = '/home/dipp/Github/Master-Thesis-dipp/GeoGraphic HeatMap/Result/Geo Shape File/geo-shape.shp'

# %% [markdown]
# ## https://www.relataly.com/visualize-covid-19-data-on-a-geographic-heat-maps/291/

# %%
# Read shapefile using Geopandas
geo_df = gpd.read_file(shapefile)
geo_df
# Out:
#     Country Co     Country Na  Connection   Latitude   Longitude  Population  \
# 0           CA         Canada   1541103.0  61.066692 -107.991707    37589262
# 1           US  United States  35310671.0  39.783730 -100.445882   328239523
# 2           IN          India   5133941.0  22.351115   78.667743  1366417754
# 3           ES          Spain    203364.0  39.326068   -4.837979    47076781
# 4           AU      Australia    830736.0 -24.776109  134.755000    25364307
# ..         ...            ...         ...        ...         ...         ...
# 193         UZ     Uzbekistan         3.0  41.323730   63.952810    33580650
# 194         KI       Kiribati         1.0   0.344861  173.664177      117606
# 195         NE          Niger         1.0  35.000074  104.999927    23310715
# 196         GA          Gabon         1.0  -0.899969   11.689970     2172579
# 197         ME     Montenegro         1.0  23.658512 -102.007710      622137
#
#                         geometry
# ...

# %%
geo_df.drop(['Connection', 'Latitude', 'Longitude', 'Population'], axis=1)
# Out:
#     Country Co     Country Na                     geometry
# 0           CA         Canada  POINT (-107.99171 61.06669)
# 1           US  United States  POINT (-100.44588 39.78373)
# 2           IN          India    POINT (78.66774 22.35111)
# 3           ES          Spain    POINT (-4.83798 39.32607)
# 4           AU      Australia  POINT (134.75500 -24.77611)
# ..         ...            ...                          ...
# 193         UZ     Uzbekistan    POINT (63.95281 41.32373)
# 194         KI       Kiribati    POINT (173.66418 0.34486)
# 195         NE          Niger   POINT (104.99993 35.00007)
# 196         GA          Gabon    POINT (11.68997 -0.89997)
# 197         ME     Montenegro  POINT (-102.00771 23.65851)
#
# [198 rows x 3 columns]

# %%
geo_df.plot(figsize=(20, 20), edgecolor='white', linewidth=1, color='lightblue')
# Out:
# <Axes: >
