# %%
import pandas as pd
import matplotlib.pyplot as plt
import csv
import seaborn as sns

# %%
test_path = '/global/D1/projects/umod/dipp/playground/result_graph/degree_all_sample.csv'

# %%
ds = pd.read_csv(test_path)
# print(ds.to_string())
ds.info()
plt.hist(ds.iloc[:, 1], bins=45)
plt.yscale('log')
plt.xlabel('Degree')
plt.ylabel('Count')
plt.savefig('/home/dipp/Github/Master-Thesis-dipp/DEGREE-PLOT/test.pdf', format='pdf', papertype='letter')
plt.show()

#plt.savefig('/home/dipp/Github/Master-Thesis-dipp/DEGREE-PLOT/test.png', format='png', papertype='a4')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201842 entries, 0 to 201841
# Data columns (total 2 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   1041821409608196099  201842 non-null  int64
#  1   372                  201842 non-null  int64
# dtypes: int64(2)
# memory usage: 3.1 MB
# /home/dipp/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error in 3.6
