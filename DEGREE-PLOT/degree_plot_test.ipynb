# %%
import pandas as pd
import matplotlib.pyplot as plt
import csv

# %%
cols = ['Degree', 'Count']
file_name_all = "/home/dipp/Github/Master-Thesis-dipp/DEGREE-PLOT/degree_all.csv"
file_name_in = "/home/dipp/Github/Master-Thesis-dipp/DEGREE-PLOT/degree_in.csv"
file_name_out = "/home/dipp/Github/Master-Thesis-dipp/DEGREE-PLOT/degree_out.csv"

# %%
def csv_to_df(file_name):
    with open(file_name, newline='') as f:
        reader = csv.reader(f)
        data = list(b for a, b in reader)
        res = [(i, data.count(i)) for i in set(data)]
        df = pd.DataFrame(res, columns=cols)
    
    return df

# %%
df_all = csv_to_df(file_name_all)
df_in = csv_to_df(file_name_in)
df_out = csv_to_df(file_name_out)

# %%
df_all.sort_values(by=['Count'])
# Out:
#      Degree  Count
# 0      1107      1
# 290   61059      1
# 289     613      1
# 288  174039      1
# 287   85774      1
# ..      ...    ...
# 206     116      3
# 142      44      4
# 43       35      4
# 431      17      4
# 16        1      7
#
# [435 rows x 2 columns]

# %%
df_all.plot.line(x='Degree', y='Count')
# Out:
# <AxesSubplot:xlabel='Degree'>

# %%
x = df_all['Degree']
y = df_all['Count']

# %%
x
# Out:
# 0       1107
# 1       1414
# 2        147
# 3        262
# 4         12
#        ...
# 430      942
# 431       17
# 432    29461
# 433    25150
# 434    17464
# Name: Degree, Length: 435, dtype: object

# %%
plt.loglog(x,y)

# %%
plt.loglog(x,y)

# %%
plt.plot(x,y)

# %%
df_out.plot.hist(bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
plt.hist(df_all)
# Out:
# (array([[ 44.,  43.,  44.,  43.,  43.,  44.,  43.,  44.,  43.,  44.],
#         [435.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.]]),
#  array([0.0, 43.4, 86.8, 130.2, 173.6, 217.0, 260.4, 303.8, 347.2,
#         390.59999999999997, 434.0], dtype=object),
#  <a list of 2 BarContainer objects>)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))

plt.xlabel('Degree')
plt.ylabel('Freq')
# Out:
# Text(0, 0.5, 'Freq')
