# %%
#US → GB, CA, IN, AU, IT, JP, DE, HK, ZA, NL

import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point

# Coordinates for US
us_coordinates = (-100.445882, 39.7837304)

# Coordinates for the 10 countries
countries = {
    'GB': ('-3.2765753', '54.7023545'),  # Great Britain (London)
    'CA': ('-107.991707', '61.0666922'),  # Canada (Toronto)
    'IN': ('78.6677428', '22.3511148'),  # India (New Delhi)
    'AU': ('134.755', '-24.7761086'),  # Australia (Sydney)
    'IT': ('12.674297', '42.6384261'),  # Italy (Rome)
    'JP': ('139.2394179', '36.5748441'),  # Japan (Tokyo)
    'DE': ('10.4478313', '51.1638175'),  # Germany (Berlin)
    'HK': ('114.1849161', '22.350627'),  # Hong Kong
    'ZA': ('24.991639', '-28.8166236'),  # South Africa (Cape Town)
    'NL': ('5.541246849406163', '52.24764975')  # Netherlands (Amsterdam)
}

# Create a GeoDataFrame with the 10 countries
gdf = gpd.GeoDataFrame(
    {'Country': countries.keys()},
    geometry=[Point(float(lon), float(lat)) for lon, lat in countries.values()],
    crs='EPSG:4326'
)

# Create a simple world map
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Plot the world map
ax = world.plot(figsize=(12, 12), color='lightgray', edgecolor='k')

# Plot the points for the 10 countries
gdf.plot(ax=ax, marker='o', color='red', markersize=10)

# Add arrows from the US to each country
arrowprops = dict(arrowstyle='-|>', color='blue', lw=2)
for idx, row in gdf.iterrows():
    plt.annotate(
        '', xy=row.geometry.coords[0], xytext=us_coordinates,
        arrowprops=arrowprops, annotation_clip=False
    )

# Set plot limits
ax.set_xlim([-180, 180])
ax.set_ylim([-90, 90])

# Show the map
plt.title('Top 10 destination countries of Tweets made from the United States')
plt.savefig('/home/dipp/Github/Master-Thesis-dipp/Geo_Map_Final/Result/top_5_source_US_new.pdf', bbox_inches='tight')
plt.show()

# %%
# GB → US, CA, IN, NG, MX, AU, ZA, MY, HK, DE

import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point

# Coordinates for Great Britain
gb_coordinates = (-3.2765753, 54.7023545)  # London, GB

# Coordinates for the 10 destinations
destinations = {
    'US': (-100.445882, 39.7837304),  # United States (New York City)
    'CA': (-107.991707, 61.0666922),  # Canada (Toronto)
    'IN': (78.6677428, 22.3511148),  # India (New Delhi)
    'NG': (7.9999721, 9.6000359),  # Nigeria (Lagos)
    'MX': (-102.0077097, 23.6585116),  # Mexico (Mexico City)
    'AU': (134.755, -24.7761086),  # Australia (Sydney)
    'ZA': (24.991639, -28.8166236),  # South Africa (Cape Town)
    'MY': (101.6868, 3.1390),  # Malaysia (Kuala Lumpur)
    'HK': (114.1849161, 22.350627),  # Hong Kong
    'DE': (10.4478313, 51.1638175)  # Germany (Berlin)
}

# Create a GeoDataFrame with GB as the starting point
gdf = gpd.GeoDataFrame(
    {'Destination': destinations.keys()},
    geometry=[Point(float(lon), float(lat)) for lon, lat in destinations.values()],
    crs='EPSG:4326'
)

# Create a simple world map
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Plot the world map
ax = world.plot(figsize=(12, 12), color='lightgray', edgecolor='k')

# Plot the point for Great Britain
gdf_start = gpd.GeoDataFrame({'Destination': ['GB']}, geometry=[Point(gb_coordinates)], crs='EPSG:4326')
gdf_start.plot(ax=ax, marker='o', color='green', markersize=10)

# Plot the points for the 10 destinations
gdf.plot(ax=ax, marker='o', color='red', markersize=10)

# Add arrows from Great Britain to each destination
arrowprops = dict(arrowstyle='-|>', color='blue', lw=2)
for idx, row in gdf.iterrows():
    plt.annotate(
        '', xy=row.geometry.coords[0], xytext=gb_coordinates,
        arrowprops=arrowprops, annotation_clip=False
    )

# Set plot limits
ax.set_xlim([-180, 180])
ax.set_ylim([-90, 90])

# Show the map
plt.title('Top 10 destination countries of Tweets made from Great Britain')
plt.savefig('/home/dipp/Github/Master-Thesis-dipp/Geo_Map_Final/Result/top_5_source_GB_new.pdf', bbox_inches='tight')
plt.show()

# %%
# IN → US, GB, CA, AU, AE, SA, DE, PK, NG, ZA

import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point

# Coordinates for India (IN)
in_coordinates = (78.6677428, 22.3511148)

# Coordinates for the 10 destinations
destinations = {
    'US': (-100.445882, 39.7837304),  # United States (New York)
    'GB': (-3.2765753, 54.7023545),  # Great Britain (London)
    'CA': (-107.991707, 61.0666922),  # Canada (Toronto)
    'AU': (134.755, -24.7761086),  # Australia (Sydney)
    'AE': (53.9994829, 24.0002488),  # United Arab Emirates (Dubai)
    'SA': (42.3528328, 25.6242618),  # Saudi Arabia (Riyadh)
    'DE': (10.4478313, 51.1638175),  # Germany (Berlin)
    'PK': (71.247499, 30.3308401),  # Pakistan (Karachi)
    'NG': (7.9999721, 9.6000359),  # Nigeria (Lagos)
    'ZA': (24.991639, -28.8166236)  # South Africa (Cape Town)
}

# Create a GeoDataFrame with the 10 destinations
gdf = gpd.GeoDataFrame(
    {'Country': destinations.keys()},
    geometry=[Point(float(lon), float(lat)) for lon, lat in destinations.values()],
    crs='EPSG:4326'
)

# Create a simple world map
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Plot the world map
ax = world.plot(figsize=(12, 12), color='lightgray', edgecolor='k')

# Plot the points for the 10 destinations
gdf.plot(ax=ax, marker='o', color='red', markersize=10)

# Add arrows from India to each destination
arrowprops = dict(arrowstyle='-|>', color='blue', lw=2)
for idx, row in gdf.iterrows():
    plt.annotate(
        '', xy=row.geometry.coords[0], xytext=in_coordinates,
        arrowprops=arrowprops, annotation_clip=False
    )

# Set plot limits
ax.set_xlim([-180, 180])
ax.set_ylim([-90, 90])

# Show the map
plt.title('Top 10 destination countries of Tweets made from India')
plt.savefig('/home/dipp/Github/Master-Thesis-dipp/Geo_Map_Final/Result/top_5_source_IN_new.pdf', bbox_inches='tight')
plt.show()

# %%
# CA → US, GB, IN, AU, DE, NG, HK, ZA, PH, FR
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point

# Coordinates for Canada (CA)
ca_coordinates = (-107.991707, 61.0666922)

# Coordinates for the 10 destinations
destinations = {
    'US': ('-100.445882', '39.7837304'),  # United States (New York City)
    'GB': ('-3.2765753', '54.7023545'),  # Great Britain (London)
    'IN': ('78.6677428', '22.3511148'),  # India (New Delhi)
    'AU': ('134.755', '-24.7761086'),  # Australia (Sydney)
    'DE': ('10.4478313', '51.1638175'),  # Germany (Berlin)
    'NG': ('7.9999721', '9.6000359'),  # Nigeria (Lagos)
    'HK': ('114.1849161', '22.350627'),  # Hong Kong
    'ZA': ('24.991639', '-28.8166236'),  # South Africa (Cape Town)
    'PH': ('122.7312101', '12.7503486'),  # Philippines (Manila)
    'FR': ('1.8883335', '46.603354')  # France (Paris)
}

# Create a GeoDataFrame with the 10 destinations
gdf = gpd.GeoDataFrame(
    {'Destination': destinations.keys()},
    geometry=[Point(float(lon), float(lat)) for lon, lat in destinations.values()],
    crs='EPSG:4326'
)

# Create a simple world map
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Plot the world map
ax = world.plot(figsize=(12, 12), color='lightgray', edgecolor='k')

# Plot the points for the 10 destinations
gdf.plot(ax=ax, marker='o', color='red', markersize=10)

# Add arrows from Canada (CA) to each destination
arrowprops = dict(arrowstyle='-|>', color='blue', lw=2)
for idx, row in gdf.iterrows():
    plt.annotate(
        '', xy=row.geometry.coords[0], xytext=ca_coordinates,
        arrowprops=arrowprops, annotation_clip=False
    )

# Set plot limits
ax.set_xlim([-180, 180])
ax.set_ylim([-90, 90])

# Show the map
plt.title('Top 10 destination countries of Tweets made from Canada')
plt.savefig('/home/dipp/Github/Master-Thesis-dipp/Geo_Map_Final/Result/top_5_source_CA_new.pdf', bbox_inches='tight')
plt.show()

# %%
# AU → US, GB, CA, IN, ID, DE, HK, JP, NZ, CH

import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point

# Coordinates for Australia
au_coordinates = (134.755, -24.7761086)

# Coordinates for the 10 destinations
destinations = {
    'US': (-100.445882, 39.7837304),  # United States (New York)
    'GB': (-3.2765753, 54.7023545),   # Great Britain (London)
    'CA': (-107.991707, 61.0666922),  # Canada (Toronto)
    'IN': (78.6677428, 22.3511148),   # India (New Delhi)
    'ID': (117.8902853, -2.4833826),  # Indonesia (Jakarta)
    'DE': (10.4478313, 51.1638175),   # Germany (Berlin)
    'HK': (114.1849161, 22.350627),  # Hong Kong
    'JP': (139.2394179, 36.5748441),  # Japan (Tokyo)
    'NZ': (172.8344077, -41.5000831),  # New Zealand (Auckland)
    'CH': (8.2319736, 46.7985624)   # Switzerland
}

# Create a GeoDataFrame with the 10 destinations
gdf = gpd.GeoDataFrame(
    {'Country': destinations.keys()},
    geometry=[Point(float(lon), float(lat)) for lon, lat in destinations.values()],
    crs='EPSG:4326'
)

# Create a simple world map
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Plot the world map
ax = world.plot(figsize=(12, 12), color='lightgray', edgecolor='k')

# Plot the points for Australia and the 10 destinations
gdf.plot(ax=ax, marker='o', color='red', markersize=10)
plt.annotate('AU', xy=au_coordinates, xytext=(au_coordinates[0] + 15, au_coordinates[1]))

# Add arrows from Australia to each destination
arrowprops = dict(arrowstyle='-|>', color='blue', lw=2)
for idx, row in gdf.iterrows():
    plt.annotate(
        '', xy=au_coordinates, xytext=row.geometry.coords[0],
        arrowprops=arrowprops, annotation_clip=False
    )

# Set plot limits
ax.set_xlim([-180, 180])
ax.set_ylim([-90, 90])

# Show the map
plt.title('Top 10 destination countries of Tweets made from Australia')
plt.savefig('/home/dipp/Github/Master-Thesis-dipp/Geo_Map_Final/Result/top_5_source_AU_new.pdf', bbox_inches='tight')
plt.show()
